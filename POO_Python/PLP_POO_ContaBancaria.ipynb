# %%
from PLP_POO_Exceptions import SaldoInsuficienteException

class ContaBancaria:

  def __init__(self, saldo, titular):
    self._saldo = saldo ##transformando o saldo em um atributo protegido
    self.titular = titular

  def depositar(self, valor):
    self._saldo = self._saldo + valor
    print("Depósito confirmado. Saldo atual:", self._saldo)

  def sacar(self, valor):
    if valor > self._saldo:
      raise SaldoInsuficienteException("Saldo Insuficiente.")
    self._saldo = self._saldo + valor
    print("Saque confirmado. Saldo atual:", self._saldo)


## Objetos
conta1 = ContaBancaria(1000, "Rebecca")
conta1.depositar(100)
conta1.sacar(2000)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-19807fde33cb> in <cell line: 1>()
# ----> 1 from PLP_POO_Exceptions import SaldoInsuficienteException
#       2
#       3 class ContaBancaria:
#       4
#       5   def __init__(self, saldo, titular):
#
# ModuleNotFoundError: No module named 'PLP_POO_Exceptions'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
