# %%
class SaldoInsuficienteException(Exception):
  def __init__(self, mensagem):
    super().__init__(mensagem)
    self.mensagem = mensagem

  def __str__(self):
    return f"Erro: {self.mensagem}"

teste = SaldoInsuficienteException("deu ruim")
teste.__str__()
# Out:
# 'Erro: deu ruim'
